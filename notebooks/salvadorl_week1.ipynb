# %% [markdown]
# # Spark Setup

# %% [markdown]
# ## Objective
# - Determine the tools required for a minimal working setup involving big data

# %% [markdown]
# ## Hypothesis
# - A minimal working setup using big data requires a framework of compatible tools

# %% [markdown]
# ## Procedure

# %%
# Run this cell
# !pip install pyspark
# !pip install findspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.2-py2.py3-none-any.whl size=317812365 sha256=8b1f59c22345ab54e7a6af32967c2cfa5b9482609518a3cd0f9ac5ad5599470b
#   Stored in directory: /root/.cache/pip/wheels/34/34/bd/03944534c44b677cd5859f248090daa9fb27b3c8f8e5f49574
# Successfully built pyspark
# ...

# %%
# Run this cell
# !pip install awscli
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 64.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %%
# Run this cell
import findspark
findspark.init()
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .master('local[*]') \
        .appName('Basics') \
        .getOrCreate()

print(spark.version)
# Out:
# 3.5.2

# %%
# Run this cell
# !aws s3 ls --no-sign-request s3://ooni-data-eu-fra/
# Out:
#                            PRE /
#                            PRE archives-raw/
#                            PRE autoclaved/
#                            PRE canned/
#                            PRE clickhouse_export/
#                            PRE ip2country-as/
#                            PRE jsonl/
#                            PRE metadb/
#                            PRE pg_backup/
#                            PRE raw/

# %%
# Run this cell
# !wget http://napierone.com.s3-eu-north-1.amazonaws.com/NapierOne/Data/CSV/CSV-small.zip
# Out:
# --2024-09-08 04:06:49--  http://napierone.com.s3-eu-north-1.amazonaws.com/NapierOne/Data/CSV/CSV-small.zip
# Resolving napierone.com.s3-eu-north-1.amazonaws.com (napierone.com.s3-eu-north-1.amazonaws.com)... 3.5.217.62, 3.5.216.50
# Connecting to napierone.com.s3-eu-north-1.amazonaws.com (napierone.com.s3-eu-north-1.amazonaws.com)|3.5.217.62|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46485718 (44M) [application/x-zip-compressed]
# Saving to: ‘CSV-small.zip’
#
# CSV-small.zip       100%[===================>]  44.33M  9.52MB/s    in 7.6s
#
# 2024-09-08 04:06:57 (5.83 MB/s) - ‘CSV-small.zip’ saved [46485718/46485718]

# %%
# Run this cell
# !mkdir /content/for_csv/
# !unzip /content/CSV-small.zip -d /content/for_csv/
# Out:
# Archive:  /content/CSV-small.zip
#   inflating: /content/for_csv/0001-csv.csv
#   inflating: /content/for_csv/0002-csv.csv
#   inflating: /content/for_csv/0003-csv.csv
#   inflating: /content/for_csv/0004-csv.csv
#   inflating: /content/for_csv/0005-csv.csv
#   inflating: /content/for_csv/0006-csv.csv
#   inflating: /content/for_csv/0007-csv.csv
#   inflating: /content/for_csv/0008-csv.csv
#   inflating: /content/for_csv/0009-csv.csv
#   inflating: /content/for_csv/0010-csv.csv
#   inflating: /content/for_csv/0011-csv.csv
#   inflating: /content/for_csv/0012-csv.csv
#   inflating: /content/for_csv/0013-csv.csv
#   inflating: /content/for_csv/0014-csv.csv
#   inflating: /content/for_csv/0015-csv.csv
#   inflating: /content/for_csv/0016-csv.csv
#   inflating: /content/for_csv/0017-csv.csv
#   inflating: /content/for_csv/0018-csv.csv
#   inflating: /content/for_csv/0019-csv.csv
#   inflating: /content/for_csv/0020-csv.csv
#   inflating: /content/for_csv/0021-csv.csv
# ...

# %% [markdown]
# ## Observation and Analysis
#
# Based on my observation, after running through the procedure the installation and configuration of pyspark and findspark libraries were successfully installed, and I think that awscli was used to interact with AWS S3. With that, Spark can start linking to S3 data sources and function on its own with this configuration. Furthermore, I believe that PySpark is operating successfully in 3.5.2 version by setting it up in the Spark session.
#
# In terms of analyzing the system's ability to display and communicate with distant datasets on AWS, it is demonstrated by the effective connection to the bucket. I think that the capacity to obtain big datasets like this using simple run on the commands is through downloading a CSV file from a different S3 bucket like napierone.
#
# Lastly, throughout the whole downloads and processes of the file, there are 1,000 separate CSV files that were successfully unzipped and retrieved which are available for further analysis within the Spark environment. Hence, this signifies that the platform is ready to manage organized data and get it ready for additional analysis and processing in Spark.

# %% [markdown]
# ## Conclusion
#
# Therefore, I conclude that, to determine the tools required for a minimal working setup involving big data and to use PySpark for big data, I first need to install the necessary tools such as pyspark to process large datasets, findspark to initialize Spark with Python, and awscli for accessing cloud-stored data. After setting up Spark, I can connect to the data stored on AWS S3, download datasets, and prepare them for analysis. With that being said, to start processing big data, I will need PySpark to handle large datasets across multiple computers, AWS CLI to access data stored in the cloud and a tool like wget to download datasets from the internet. Hence, throughout running the procedure I was able to satisfy the objective and confirmed the hypothesis as my Spark environment is now ready to handle large-scale data processing tasks.
